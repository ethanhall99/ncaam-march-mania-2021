# %% [markdown]
# ### Notes
# - Train fully on season data, test on conference tournament

# %%
import math
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Global Variables
minSeason = 2021

pd.options.mode.chained_assignment = None

# %%
# read in files
MMasseyOrdinals = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/MMasseyOrdinals.csv')
MRegularSeasonDetailedResults = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/MRegularSeasonDetailedResults.csv')
MTeamConferences = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/MTeamConferences.csv')
Conferences = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/Conferences.csv')
MTeams = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/MTeams.csv')
MConferenceTourneyGames = pd.read_csv('/Users/ethanhall/Desktop/Data/ncaam-march-mania-2021/MDataFiles_Stage2/MConferenceTourneyGames.csv')

# %%
# build teams dataset
dfTeamConf = MTeamConferences[MTeamConferences['Season'] == minSeason]
dfTeamConf = pd.merge(dfTeamConf, Conferences, on = 'ConfAbbrev', how = 'left')
dfTeamConf = pd.merge(dfTeamConf, MTeams, on = 'TeamID', how = 'left')
dfTeamConf = dfTeamConf[['TeamID'
                        ,'TeamName'
                        ,'Description'
                        ,'PowerFive']]


dfOppTeamConf = MTeamConferences[MTeamConferences['Season'] == minSeason]
dfOppTeamConf = pd.merge(dfOppTeamConf, Conferences, on = 'ConfAbbrev', how = 'left')
dfOppTeamConf = pd.merge(dfOppTeamConf, MTeams, on = 'TeamID', how = 'left')
dfOppTeamConf = dfOppTeamConf[['TeamID'
                        ,'TeamName'
                        ,'Description'
                        ,'PowerFive']]
dfOppTeamConf.columns = ['OppTeamID', 'OppTeamName', 'OppDescription', 'OppPowerFive']


dfTeamConf.head(n=10)
# Out:
#    TeamID        TeamName                    Description  PowerFive
# 0    1101     Abilene Chr           Southland Conference          0
# 1    1102       Air Force       Mountain West Conference          0
# 2    1103           Akron        Mid-American Conference          0
# 3    1104         Alabama        Southeastern Conference          1
# 4    1105     Alabama A&M  Southwest Athletic Conference          0
# 5    1106      Alabama St  Southwest Athletic Conference          0
# 6    1107     SUNY Albany        America East Conference          0
# 7    1108       Alcorn St  Southwest Athletic Conference          0
# 8    1110   American Univ                 Patriot League          0
# 9    1111  Appalachian St            Sun Belt Conference          0

# %%
# Game details dataset
dfGame = MRegularSeasonDetailedResults[MRegularSeasonDetailedResults['Season'] == minSeason]
dayAdj = min(dfGame['DayNum']) - 1

gameCols = ["DayNum", "TeamID", "OppTeamID", "WinLoss", "PF", "PA", 
            "NumOT", "FGM", "FGA", "FGM3", "FGA3", "FTM", "FTA", 
            "OR", "DR", "Ast", "TO", "Stl", "Blk", "Fouls"]

dfGameWinner = dfGame[["DayNum", "WTeamID", "LTeamID", "WScore", "LScore", 
                       "NumOT", "WFGM", "WFGA", "WFGM3", "WFGA3", "WFTM", "WFTA", 
                       "WOR", "WDR", "WAst", "WTO", "WStl", "WBlk", "WPF"]]
dfGameWinner.insert(loc = 3, column = 'WinLoss', value = 1)
dfGameWinner.columns = gameCols

dfGameLoser = dfGame[["DayNum", "LTeamID", "WTeamID", "LScore", "WScore", 
                      "NumOT", "LFGM", "LFGA", "LFGM3", "LFGA3", "LFTM", "LFTA", 
                      "LOR", "LDR", "LAst", "LTO", "LStl", "LBlk", "LPF"]]
dfGameLoser.insert(loc = 3, column = 'WinLoss', value = 0)
dfGameLoser.columns = gameCols


dfGameDetails = dfGameWinner.append(dfGameLoser)
dfGameDetails = pd.merge(dfOppTeamConf, dfGameDetails, on = 'OppTeamID', how = 'left')
dfGameDetails = pd.merge(dfTeamConf, dfGameDetails, on = 'TeamID', how = 'left')

dfGameDetails['DayNum'] = dfGameDetails['DayNum'] - dayAdj
dfGameDetails.insert(loc = 8, column = 'WeekNum', value = np.ceil(dfGameDetails['DayNum']/7).astype(int))

print(len(dfGameDetails.index)) #7710
dfGameDetails.head(n=10)
# Out:
# 7710
#     TeamID     TeamName               Description  PowerFive  OppTeamID  \
# 0     1101  Abilene Chr      Southland Conference          0       1116
# 1     1101  Abilene Chr      Southland Conference          0       1122
# 2     1101  Abilene Chr      Southland Conference          0       1146
# 3     1101  Abilene Chr      Southland Conference          0       1146
# 4     1101  Abilene Chr      Southland Conference          0       1190
# 5     1101  Abilene Chr      Southland Conference          0       1223
# 6     1101  Abilene Chr      Southland Conference          0       1223
# 7     1101  Abilene Chr      Southland Conference          0       1230
# 8     1101  Abilene Chr      Southland Conference          0       1230
# 9     1101  Abilene Chr      Southland Conference          0       1249
# 10    1101  Abilene Chr      Southland Conference          0       1249
# 11    1101  Abilene Chr      Southland Conference          0       1249
# 12    1101  Abilene Chr      Southland Conference          0       1303
# 13    1101  Abilene Chr      Southland Conference          0       1311
# 14    1101  Abilene Chr      Southland Conference          0       1358
# 15    1101  Abilene Chr      Southland Conference          0       1358
# 16    1101  Abilene Chr      Southland Conference          0       1368
# 17    1101  Abilene Chr      Southland Conference          0       1372
# 18    1101  Abilene Chr      Southland Conference          0       1372
# 19    1101  Abilene Chr      Southland Conference          0       1394
# 20    1101  Abilene Chr      Southland Conference          0       1394
# 21    1101  Abilene Chr      Southland Conference          0       1403
# 22    1101  Abilene Chr      Southland Conference          0       1470
# 23    1102    Air Force  Mountain West Conference          0       1129
# 24    1102    Air Force  Mountain West Conference          0       1129
#
#        OppTeamName               OppDescription  OppPowerFive  WeekNum  \
# 0         Arkansas      Southeastern Conference             1        4
# 1      Austin Peay       Ohio Valley Conference             0        1
# 2    Cent Arkansas         Southland Conference             0        9
# 3    Cent Arkansas         Southland Conference             0       14
# 4             ETSU          Southern Conference             0        1
# 5      Houston Bap         Southland Conference             0        7
# 6      Houston Bap         Southland Conference             0       12
# 7   Incarnate Word         Southland Conference             0       10
# 8   Incarnate Word         Southland Conference             0       15
# 9            Lamar         Southland Conference             0        6
# 10           Lamar         Southland Conference             0       11
# 11           Lamar         Southland Conference             0       16
# 12        NE Omaha                Summit League             0        1
# 13     Nicholls St         Southland Conference             0       16
# 14  Sam Houston St         Southland Conference             0       14
# 15  Sam Houston St         Southland Conference             0        9
# 16    SE Louisiana         Southland Conference             0        8
# 17       SF Austin         Southland Conference             0       10
# 18       SF Austin         Southland Conference             0       15
# 19  TAM C. Christi         Southland Conference             0       11
# 20  TAM C. Christi         Southland Conference             0       12
# 21      Texas Tech            Big 12 Conference             1        3
# 22     Tarleton St  Western Athletic Conference             0        2
# 23        Boise St     Mountain West Conference             0        7
# 24        Boise St     Mountain West Conference             0        7
#
#     DayNum  ...  FGA3  FTM  FTA  OR  DR  Ast  TO  Stl  Blk  Fouls
# 0       28  ...    22    9   15   8  17   13  12    3    4      0
# 1        3  ...     9   17   29   5  20   12  15   12    1      0
# 2       60  ...    31   13   18   8  23   29  12   11    6      0
# 3       95  ...    23   14   22   6  25   23  11    9    1     25
# 4        1  ...    23   17   27   6  24   14  15    8    3      0
# 5       43  ...    22    9   11  13  27   17  13    6    3      0
# 6       78  ...    28    9   18  17  23   26  19   18    4      0
# 7       67  ...    23   19   25  12  26   17  12    2    1      0
# 8      102  ...    33   13   14  13  29   22  13   14    5     18
# 9       39  ...    20   14   21  15  23   21  13   11    3      0
# 10      74  ...    22    6   12   9  21   20   7   11    2      0
# 11     108  ...    21   16   21  11  21   22  10   11    2     12
# 12       4  ...    12   12   20  10  22   15  14    9    0      0
# 13     109  ...    22   10   11  13  38   19  16   12    3     15
# 14      92  ...    19   18   22   8  20   21  14    6    3     12
# 15      57  ...    19    8   15  11  18   21  11    6    3     20
# 16      53  ...    24   19   27   9  22   21  14   16    5      0
# 17      64  ...    24   24   29  12  24   12  11    7    5      0
# 18      99  ...    13   15   26   7  18   13  22    4    1     30
# 19      76  ...    15   14   21  10  20   20   8    8    3      0
# 20      81  ...    26   22   27   5  25   19  13   13    6      0
# 21      15  ...    18    6    9   3  20    6  20    8    3      0
# 22      11  ...    27   14   22  10  19   15  14   10    2      0
# 23      43  ...    21    8   12   2  17   10  14    6    1      0
# 24      45  ...    20   12   13   2  17   11  12    2    2      0
#
# [25 rows x 27 columns]

# %%
# Summarize Game Stats
dfSeasonStats = dfGameDetails.groupby(['TeamID', 'TeamName', 'Description', 'PowerFive']).agg(
    GP = pd.NamedAgg(column = "WinLoss", aggfunc = 'size'),
    Wins = pd.NamedAgg(column = "WinLoss", aggfunc = sum),
    Loss = pd.NamedAgg(column = "WinLoss", aggfunc = min),
    PF = pd.NamedAgg(column = "PF", aggfunc = 'mean'),
    PA = pd.NamedAgg(column = "PA", aggfunc = 'mean'),
    FGPct = pd.NamedAgg(column = "FGM", aggfunc = 'mean'),
    FGM = pd.NamedAgg(column = "FGM", aggfunc = sum),
    FGA = pd.NamedAgg(column = "FGA", aggfunc = sum),
    FG3Pct = pd.NamedAgg(column = "FGM3", aggfunc = 'mean'),
    FGM3 = pd.NamedAgg(column = "FGM3", aggfunc = sum),
    FGA3 = pd.NamedAgg(column = "FGA3", aggfunc = sum),
    FTPct = pd.NamedAgg(column = "FTM", aggfunc = 'mean'),
    FTM = pd.NamedAgg(column = "FTM", aggfunc = sum),
    FTA = pd.NamedAgg(column = "FTA", aggfunc = sum),
    Reb = pd.NamedAgg(column = "OR", aggfunc = sum),
    OReb = pd.NamedAgg(column = "OR", aggfunc = 'mean'),
    DReb = pd.NamedAgg(column = "DR", aggfunc = 'mean'),
    Ast = pd.NamedAgg(column = "Ast", aggfunc = 'mean'),
    TO = pd.NamedAgg(column = "TO", aggfunc = 'mean'),
    Stl = pd.NamedAgg(column = "Stl", aggfunc = 'mean'),
    Blk = pd.NamedAgg(column = "Blk", aggfunc = 'mean')
)

dfSeasonStats['Loss'] =  dfSeasonStats['GP'] - dfSeasonStats['Wins']
dfSeasonStats['FGPct'] = (dfSeasonStats['FGM']/dfSeasonStats['FGA'])*100
dfSeasonStats['FG3Pct'] = (dfSeasonStats['FGM3']/dfSeasonStats['FGA3'])*100
dfSeasonStats['FTPct'] = (dfSeasonStats['FTM']/dfSeasonStats['FTA'])*100
dfSeasonStats['Reb'] = dfSeasonStats['OReb'] + dfSeasonStats['DReb']


dfSeasonStats.head(n=10)
# Out:
#                                                                GP  Wins  Loss  \
# TeamID TeamName       Description                   PowerFive
# 1101   Abilene Chr    Southland Conference          0          23    19     4
# 1102   Air Force      Mountain West Conference      0          25     5    20
# 1103   Akron          Mid-American Conference       0          21    13     8
# 1104   Alabama        Southeastern Conference       1          30    24     6
# 1105   Alabama A&M    Southwest Athletic Conference 0          15     6     9
# 1106   Alabama St     Southwest Athletic Conference 0          18     4    14
# 1107   SUNY Albany    America East Conference       0          16     7     9
# 1108   Alcorn St      Southwest Athletic Conference 0          19     6    13
# 1110   American Univ  Patriot League                0          10     4     6
# 1111   Appalachian St Sun Belt Conference           0          24    13    11
#
#                                                                       PF  \
# TeamID TeamName       Description                   PowerFive
# 1101   Abilene Chr    Southland Conference          0          76.304348
# 1102   Air Force      Mountain West Conference      0          58.720000
# 1103   Akron          Mid-American Conference       0          76.571429
# 1104   Alabama        Southeastern Conference       1          79.566667
# 1105   Alabama A&M    Southwest Athletic Conference 0          63.333333
# 1106   Alabama St     Southwest Athletic Conference 0          64.222222
# 1107   SUNY Albany    America East Conference       0          69.375000
# 1108   Alcorn St      Southwest Athletic Conference 0          66.105263
# 1110   American Univ  Patriot League                0          69.100000
# 1111   Appalachian St Sun Belt Conference           0          68.166667
#
#                                                                       PA  \
# TeamID TeamName       Description                   PowerFive
# 1101   Abilene Chr    Southland Conference          0          61.739130
# 1102   Air Force      Mountain West Conference      0          71.920000
# 1103   Akron          Mid-American Conference       0          72.761905
# 1104   Alabama        Southeastern Conference       1          69.766667
# 1105   Alabama A&M    Southwest Athletic Conference 0          67.200000
# 1106   Alabama St     Southwest Athletic Conference 0          71.555556
# 1107   SUNY Albany    America East Conference       0          68.687500
# 1108   Alcorn St      Southwest Athletic Conference 0          75.631579
# 1110   American Univ  Patriot League                0          73.600000
# 1111   Appalachian St Sun Belt Conference           0          68.250000
#
#                                                                    FGPct  FGM  \
# TeamID TeamName       Description                   PowerFive
# 1101   Abilene Chr    Southland Conference          0          46.023564  625
# 1102   Air Force      Mountain West Conference      0          44.615385  522
# 1103   Akron          Mid-American Conference       0          43.764706  558
# 1104   Alabama        Southeastern Conference       1          43.056273  834
# 1105   Alabama A&M    Southwest Athletic Conference 0          39.976959  347
# 1106   Alabama St     Southwest Athletic Conference 0          37.958375  383
# 1107   SUNY Albany    America East Conference       0          44.733862  395
# 1108   Alcorn St      Southwest Athletic Conference 0          39.295393  435
# 1110   American Univ  Patriot League                0          44.524237  248
# 1111   Appalachian St Sun Belt Conference           0          40.509091  557
#
#                                                                 FGA  \
# TeamID TeamName       Description                   PowerFive
# 1101   Abilene Chr    Southland Conference          0